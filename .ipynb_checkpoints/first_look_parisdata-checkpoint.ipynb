# %% [markdown]
# # Repopulation Paris

# %% [markdown]
# ## First Look into Bottin Data

# %%
import pandas as pd
import geopandas as gpd

# %%
bottins = pd.read_csv("data/strict_addressing.csv")

# %%
print("size of table:", bottins.shape)
bottins.head(50)
# Out:
# size of table: (4406164, 8)
#        Unnamed: 0  page  row                               Nom  \
# 0   bpt6k6282019m   144    0                             Aaron
# 1   bpt6k6282019m   144    1                      Aaron (Mic.)
# 2   bpt6k6282019m   144    3                            Abadie
# 3   bpt6k6282019m   144    5                            Abadie
# 4   bpt6k6282019m   144    6                            Abanse
# 5   bpt6k6282019m   144    7                              Abat
# 6   bpt6k6282019m   144   13                 Abault et Coudray
# 7   bpt6k6282019m   144   14                     Abault (Paul)
# 8   bpt6k6282019m   144   15                            Abavid
# 9   bpt6k6282019m   144   16                     Abazaer (Are)
# 10  bpt6k6282019m   144   17         Abbadie (A.) et Montagnan
# 11  bpt6k6282019m   144   20                             Abbal
# 12  bpt6k6282019m   144   21               Abbatucci (Séverin)
# 13  bpt6k6282019m   144   24                 Abbatucci # (Th.)
# 14  bpt6k6282019m   144   25  Abbaye-au-Bois (communauté del')
# 15  bpt6k6282019m   144   26                           Abeille
# 16  bpt6k6282019m   144   27                           Abeille
# 17  bpt6k6282019m   144   28                              Abel
# 18  bpt6k6282019m   144   29                              Abel
# 19  bpt6k6282019m   144   31   Abel de Pujol * (de l'Institut)
# 20  bpt6k6282019m   144   32                       Abel-Loroue
# 21  bpt6k6282019m   144   33      Abel-Mouillard et E. Gaspart
# 22  bpt6k6282019m   144   34                            Abello
# 23  bpt6k6282019m   144   35                           Aberlin
# 24  bpt6k6282019m   144   36                             Abert
# 25  bpt6k6282019m   144   37                            Abette
# 26  bpt6k6282019m   144   38                           Abillot
# 27  bpt6k6282019m   144   39                              Abit
# 28  bpt6k6282019m   144   40                        Abit jeune
# 29  bpt6k6282019m   144   41                             Abler
# 30  bpt6k6282019m   144   42                            Aboire
# 31  bpt6k6282019m   144   43                           Abonnet
# 32  bpt6k6282019m   144   45                      Abraham (E.)
# 33  bpt6k6282019m   144   47                           Abraham
# 34  bpt6k6282019m   144   48                           Abraham
# 35  bpt6k6282019m   144   49          Abraham-Cliver (Edouard)
# 36  bpt6k6282019m   144   50                  Abraham-Dubois *
# 37  bpt6k6282019m   144   51           Abrahams Junior (J.-D.)
# 38  bpt6k6282019m   144   52                             Abran
# 39  bpt6k6282019m   144   53                   Abrial (Cte d')
# 40  bpt6k6282019m   144   55                              Abry
# 41  bpt6k6282019m   144   56                         Abry (J.)
# 42  bpt6k6282019m   144   57                       Absil (Mme)
# 43  bpt6k6282019m   144   58                            Absire
# 44  bpt6k6282019m   144   59            Abt (H.G.) fils et Cie
# 45  bpt6k6282019m   144   60                         Abt (Luc)
# 46  bpt6k6282019m   144   65                              Acar
# 47  bpt6k6282019m   144   66                             Acard
# 48  bpt6k6282019m   144   67                             Acard
# 49  bpt6k6282019m   144   68                    Acard (Eugène)
#
#                                       Métier                    Rue  \
# 0                                    bronzes       passage Choiseal
# 1                      manuf. de porcelaines                  Bondy
# 2                                 architecte               Provence
# 3                          tabac et estamin.           Ménilmontant
# 4                                instituteur              Sts-Pères
# 5                                    rentier                   Isly
# 6                               charpentiers                Corbeau
# 7                                   libraire     quai des Angustins
# 8                                       vins   Beaujolais-da-Temple
# 9                    cristaux et porcelaines            Pei.Ecuries
# 10                                     draps  Neuve-desBons-Enfants
# 11                                  coiffeur             Parc-Royal
# 12                        député de la Corse          place Vendôme
# 13     maître des requêtes au conseil d'Etat            pl. Vendôme
# 14    église succursale de St-Thomas-d'Aquin                 Sèvres
# 15                                   médecin              Pépinière
# 16                                 propriét.        Faub.-St-Honoré
# 17                                 coutelier   Paradis-Poissonnière
# 18                       coke et escarhilles   Austerlitz-St-Marcel
# 19                           peintre d'hist.                 Albouy
# 20                                 chemisier            Castiglione
# 21  fab. de châles et confections pour dames         boul. St-Denis
# 22                          gainier-ébéniste                 Temple
# 23                                  coiffeur             Montmartre
# 24                                 boulanger      Ecole-de-Médecine
# 25                                 tapissier    Pont-Louis-Philippe
# 26                           peintre-vitrier              Pépinière
# 27                                 bonnetier   boul. Bonne-Nouvelle
# 28                                    propr.     St-Maar-Popincourt
# 29                     cordonnier pour dames              St-Honoré
# 30                         ligeur de dessins        Fontaine-au-Roi
# 31                                      vins    St-Jean-de-Beauvais
# 32                        fabr. de broderies       NeuveSt-Eustache
# 33                                   relieur          Parcheminerie
# 34                     vérific. des domaines                Martyrs
# 35                      cravates et foulards      Neape-St-Eustache
# 36    conseiller-référ. à la cour descomptes               Cassette
# 37                             pierres fines                 Bourse
# 38                                   bottler     Vingt-Neuf-Juillet
# 39                                    avocat                Oudinot
# 40                           ancien libraire       Basse-du-Rempart
# 41                            fab. de fleurs           Ste-Apolline
# 42                                bandagiste                 Mandar
# 43                                  tailleur               Chaillot
# 44                 fab.de chapeaux de paille              Richelieu
# 45                    fab.chapeaux de paille              Richelieu
# 46          premier pharmacien de l'Empereur              St-Honoré
# 47                       fab. de champignons              Beaubourg
# 48                                   cordier             Mouffetard
# 49                                  huissier              Richelieu
#
#        Numéro  annee
# 0   72 et 74.   1855
# 1         30.   1855
# 2          7.   1855
# 3        158.   1855
# 4         30.   1855
# 5         10.   1855
# 6         23.   1855
# 7          9.   1855
# 8          7.   1855
# 9         26.   1855
# 10         1.   1855
# 11         8.   1855
# 12     11-13.   1855
# 13  ll et 13.   1855
# 14        16.   1855
# 15        39.   1855
# 16        27.   1855
# 17        59.   1855
# 18        45.   1855
# 19        14.   1855
# 20         4.   1855
# 21         9.   1855
# 22        79.   1855
# 23       160.   1855
# 24        04.   1855
# 25        13.   1855
# 26        82.   1855
# 27        11.   1855
# 28       158.   1855
# 29       317.   1855
# 30         59   1855
# 31        22.   1855
# 32        44.   1855
# 33         2.   1855
# 34        63.   1855
# 35        36.   1855
# 36         7.   1855
# 37         1.   1855
# 38         5.   1855
# 39        22.   1855
# 40        56.   1855
# 41        33.   1855
# 42         4.   1855
# 43        18.   1855
# 44        79.   1855
# 45        64.   1855
# 46       313.   1855
# 47        36.   1855
# 48       280.   1855
# 49        92.   1855

# %%
print("number of streets in dataset:", len(bottins["Rue"].unique()))
# Out:
# number of streets in dataset: 195464

# %%
bottins_original = bottins.copy()

# %% [markdown]
# ## Paris Opendata - Voies

# %%
voies = pd.read_csv("data/opendata_voie_paris.csv", sep=";")

# %%
print("number of voies:", len(voies))
voies.head()
# Out:
# number of voies: 6542
#      N_SQ_VO  C_COINSEE C_DESI C_LIAISON                 L_VOIE  \
# 0  750004016      75056    IMP       NaN                BAUDRAN
# 1  750003821      75056    IMP       DES             CHEVALIERS
# 2  750005946      75056    RUE       DES           BONS VIVANTS
# 3  750001312      75056    RUE       NaN            JEAN HUGUES
# 4  750005774      75056    RUE       NaN  JEAN-JACQUES ROUSSEAU
#
#                  L_COURTMIN                  L_LONGMIN     C_VOIE B_FANTOIR  \
# 0              Imp. Baudran            Impasse Baudran  750560733         O
# 1       Imp. des Chevaliers     Impasse des Chevaliers  750561994         O
# 2       R. des Bons Vivants       Rue des Bons Vivants  750561106         O
# 3            R. Jean Hugues            Rue Jean Hugues  750564899         O
# 4  R. Jean-Jacques Rousseau  Rue Jean-Jacques Rousseau  750564901         O
#
#   B_OFF C_VOIE_VP                                           Geometry  \
# 0     O      0717  {"coordinates": [[2.3554518641916804, 48.82415...
# 1     O      1986  {"coordinates": [[2.3960916096233094, 48.87258...
# 2     O      1111  {"coordinates": [[2.346752283163513, 48.862212...
# 3     O      4806  {"coordinates": [[2.274705254077503, 48.868429...
# 4     O      4808  {"coordinates": [[[2.3396869374353004, 48.8620...
#
#    OBJECTID C_DOMOFF    N_SQ_CO      LENGTH  \
# 0         6        O  750001537   64.625200
# 1        59        P  750001537   77.423197
# 2       112        P  750001537   39.406151
# 3       170        O  750001537   45.962263
# 4       171        P  750001537  397.842033
#
#                            Geometry X Y
# 0  48.82415332715383,2.3558919735528483
# 1  48.87229377669366,2.3963259349268453
# 2   48.862044141078364,2.34682583693024
# 3  48.86861817275934,2.2748341164181163
# 4   48.86347293952501,2.342392728552715

# %%
#keep only columns that might be useful further on
voies = voies[["N_SQ_VO", "L_VOIE", "L_COURTMIN", "L_LONGMIN", "Geometry", "LENGTH", "Geometry X Y"]]
voies.head()
# Out:
#      N_SQ_VO                 L_VOIE                L_COURTMIN  \
# 0  750004016                BAUDRAN              Imp. Baudran
# 1  750003821             CHEVALIERS       Imp. des Chevaliers
# 2  750005946           BONS VIVANTS       R. des Bons Vivants
# 3  750001312            JEAN HUGUES            R. Jean Hugues
# 4  750005774  JEAN-JACQUES ROUSSEAU  R. Jean-Jacques Rousseau
#
#                    L_LONGMIN  \
# 0            Impasse Baudran
# 1     Impasse des Chevaliers
# 2       Rue des Bons Vivants
# 3            Rue Jean Hugues
# 4  Rue Jean-Jacques Rousseau
#
#                                             Geometry      LENGTH  \
# 0  {"coordinates": [[2.3554518641916804, 48.82415...   64.625200
# 1  {"coordinates": [[2.3960916096233094, 48.87258...   77.423197
# 2  {"coordinates": [[2.346752283163513, 48.862212...   39.406151
# 3  {"coordinates": [[2.274705254077503, 48.868429...   45.962263
# 4  {"coordinates": [[[2.3396869374353004, 48.8620...  397.842033
#
#                            Geometry X Y
# 0  48.82415332715383,2.3558919735528483
# 1  48.87229377669366,2.3963259349268453
# 2   48.862044141078364,2.34682583693024
# 3  48.86861817275934,2.2748341164181163
# 4   48.86347293952501,2.342392728552715

# %%
# prepare data for alignment
bottins["Rue"] = bottins["Rue"].str.lower()
voies["L_VOIE"] = voies["L_VOIE"].str.lower()
voies["L_COURTMIN"] = voies["L_COURTMIN"].str.lower()
voies["L_LONGMIN"] = voies["L_LONGMIN"].str.lower()

# %%
bot_voies_algn1 = bottins.join(voies.set_index("L_LONGMIN"), on="Rue")
bot_voies_algn2 = bottins.join(voies.set_index("L_VOIE"), on="Rue")
bot_voies_algn3 = bottins.join(voies.set_index("L_COURTMIN"), on="Rue")

# %%
# see how many streets were aligned
print(bot_voies_algn1["Geometry"].isna().sum())
print(bot_voies_algn2["Geometry"].isna().sum())
print(bot_voies_algn3["Geometry"].isna().sum())
# Out:
# 4228735
# 3191199
# 3793594

# %%
# start with 2nd dataframe as basis, split into aligned an not aligned data
aligned = bot_voies_algn2.loc[bot_voies_algn2["Geometry"].notna()]
not_aligned = bot_voies_algn2.loc[bot_voies_algn2["Geometry"].isna()]
not_aligned = not_aligned.drop(["N_SQ_VO", "L_COURTMIN", "L_LONGMIN", "Geometry", "LENGTH", "Geometry X Y"], axis=1)
print("aligned:", len(aligned), "not aligned:", len(not_aligned))
# Out:
# aligned: 1933426 not aligned: 3191199

# %%
# perform join with "L_COURTMIN on not_aligned dataframe"
x = not_aligned.join(voies.set_index("L_COURTMIN"), on="Rue")
aligned = aligned.append(x[x["Geometry"].notna()], ignore_index = True)
not_aligned = x[x["Geometry"].isna()]
not_aligned = not_aligned.drop(["N_SQ_VO", "L_LONGMIN", "L_VOIE", "Geometry", "LENGTH", "Geometry X Y"], axis=1)
print("aligned:", len(aligned), "not aligned:", len(not_aligned))
# Out:
# aligned: 2545967 not aligned: 2578666

# %%
# perform join with "L_LONGMIN on not_aligned dataframe"
x = not_aligned.join(voies.set_index("L_LONGMIN"), on="Rue")
aligned = aligned.append(x[x["Geometry"].notna()], ignore_index = True)
not_aligned = x[x["Geometry"].isna()]
print("aligned:", len(aligned), "not aligned:", len(not_aligned))
# Out:
# aligned: 2713723 not aligned: 2410910

# %%
not_aligned.tail()
# Out:
#             Unnamed: 0  page  row              Nom              Métier  \
# 4406148  bpt6k9780089g  1607  235            Zvang          blanchiss.
# 4406153  bpt6k9780089g  1607  246    Zweiger (Vve)       vins-restaur.
# 4406156  bpt6k9780089g  1607  252         Zwilling     déchets de cuir
# 4406157  bpt6k9780089g  1607  254  Zwinger (Henri)  agent de fabriques
# 4406162  bpt6k9780089g  1607  263         Zyssmann                 bar
#
#                                      Rue Numéro  annee  N_SQ_VO L_VOIE  \
# 4406148                  r. jules-vallès     5.   1922      NaN    NaN
# 4406153  r. des hospitalières-st-gervais    12.   1922      NaN    NaN
# 4406156                     r. de buffon    67.   1922      NaN    NaN
# 4406157               faub. poissonnière    65.   1922      NaN    NaN
# 4406162                     r. de pivoli    40.   1922      NaN    NaN
#
#         L_COURTMIN Geometry  LENGTH Geometry X Y
# 4406148        NaN      NaN     NaN          NaN
# 4406153        NaN      NaN     NaN          NaN
# 4406156        NaN      NaN     NaN          NaN
# 4406157        NaN      NaN     NaN          NaN
# 4406162        NaN      NaN     NaN          NaN

# %%
# Count how many addresses were aligned per year
annee_aligned = aligned.groupby(by=["annee"]).count()[["Nom"]]
annee_not_aligned = not_aligned.groupby(by=["annee"]).count()[["Nom"]]
df_per_year = annee_aligned.join(annee_not_aligned, lsuffix='_aligned', rsuffix='_not_aligned')

# %%
# Calculate the ratio of aligned addresses
df_per_year["ratio_aligned"] = df_per_year["Nom_aligned"] / (df_per_year["Nom_aligned"]+df_per_year["Nom_not_aligned"])
df_per_year
# Out:
#        Nom_aligned  Nom_not_aligned  ratio_aligned
# annee
# 1839         17685            25795       0.406739
# 1841         21159            29352       0.418899
# 1842         22031            30303       0.420969
# 1843         18823            26673       0.413729
# 1844         21385            28703       0.426949
# 1845         22232            29422       0.430402
# 1846         23083            30404       0.431563
# 1847         23829            32053       0.426416
# 1848         26562            34287       0.436523
# 1849         26428            32924       0.445276
# 1850         27337            32000       0.460707
# 1851         28994            32625       0.470537
# 1852         31240            32718       0.488446
# 1853         32018            33871       0.485938
# 1854         34833            35458       0.495554
# 1855         36281            36926       0.495595
# 1856         37701            37776       0.499503
# 1857         37487            38901       0.490745
# 1858         37177            39172       0.486935
# 1859         35117            38937       0.474208
# 1860         37987            44767       0.459035
# 1861         38842            46152       0.456997
# 1862         40636            48689       0.454923
# 1863         40668            49484       0.451105
# 1864         37202            50034       0.426452
# 1870         55608            47271       0.540518
# 1871         55071            44074       0.555459
# 1873         55070            43888       0.556499
# 1874         54769            44009       0.554466
# 1875         59450            46133       0.563064
# 1876         60230            46359       0.565068
# 1877         62220            47632       0.566398
# 1878         64567            47503       0.576131
# 1879         63055            47867       0.568463
# 1880         64040            47286       0.575247
# 1881         70860            50842       0.582242
# 1882         68790            48912       0.584442
# 1883         75270            51635       0.593121
# 1884         71889            49729       0.591105
# 1885         75353            52474       0.589492
# 1886         77132            53776       0.589208
# 1887         66956            52500       0.560508
# 1888         66144            51735       0.561118
# 1890         64456            49419       0.566024
# 1893         69265            49890       0.581302
# 1894         65005            51176       0.559515
# 1896         58246            53354       0.521918
# 1897         60376            53406       0.530629
# 1898         63626            53997       0.540932
# 1900         66023            54427       0.548136
# 1901         67716            54907       0.552229
# 1907         68370            53484       0.561081
# 1914         69386            54134       0.561739
# 1921         64722            53957       0.545353
# 1922         73321            57708       0.559578

# %%
aligned.tail()
# Out:
#             Unnamed: 0  page  row         Nom  \
# 2713718  bpt6k9780089g  1603  137   Woog (H.)
# 2713719  bpt6k9780089g  1604  273       Yseux
# 2713720  bpt6k9780089g  1604  305        Yver
# 2713721  bpt6k9780089g  1605   47       Yvoré
# 2713722  bpt6k9780089g  1605  106  Zadok (Dr)
#
#                                   Métier                Rue  \
# 2713718               courtier en march.  square la bruyère
# 2713719                          relieur      quai de conti
# 2713720                  boucher en gros     quai de l'oise
# 2713721  vétérinaire et maréchal-ferrant   quai de jemmapes
# 2713722                          médecin      square moncey
#
#                             Numéro  annee      N_SQ_VO       L_COURTMIN  \
# 2713718  2. (90). T. Trud. 12. 99.   1922  750004615.0   sq. la bruyère
# 2713719                         7.   1922  750004871.0     qu. de conti
# 2713720                        41.   1922  750005209.0    qu. de l'oise
# 2713721                       112.   1922  750003292.0  qu. de jemmapes
# 2713722                         3.   1922  750004558.0       sq. moncey
#
#         L_LONGMIN                                           Geometry  \
# 2713718       NaN  {"coordinates": [[2.333247399796023, 48.879067...
# 2713719       NaN  {"coordinates": [[[2.3404337067044763, 48.8560...
# 2713720       NaN  {"coordinates": [[[2.379696366149043, 48.88877...
# 2713721       NaN  {"coordinates": [[[2.367392608119634, 48.86876...
# 2713722       NaN  {"coordinates": [[[2.3306447263897896, 48.8800...
#
#               LENGTH                           Geometry X Y      L_VOIE
# 2713718    49.933780    48.87912453518579,2.332918048991286  la bruyere
# 2713719   337.957721  48.856973688745086,2.3388802711013708       conti
# 2713720   732.327618     48.89065442303185,2.38319691672075        oise
# 2713721  1922.227007  48.876028316605066,2.3665121066795267    jemmapes
# 2713722   143.281994   48.88052926002643,2.3305025235547654      moncey

# %%
aligned["Rue"]
# Out:
# 0                   provence
# 1                   provence
# 2                       isly
# 3                castiglione
# 4                     temple
#                  ...
# 2713718    square la bruyère
# 2713719        quai de conti
# 2713720       quai de l'oise
# 2713721     quai de jemmapes
# 2713722        square moncey
# Name: Rue, Length: 2713723, dtype: object

# %%
from Levenshtein import distance as lev

# %% [markdown]
# ## Paris Opendata - Adresses

# %%
adresses = pd.read_csv("data/opendata_adresse_paris.csv", sep=";")

# %%
adresses.head()
# N_SQ_VO same as with voies!
# Out:
#                             Geometry X Y  \
# 0   48.868149964330925,2.385363237327124
# 1   48.873918224142145,2.308770442174867
# 2     48.84631684220949,2.34848334292492
# 3  48.850519497345935,2.3857899214565674
# 4   48.85233571571768,2.2684341614185204
#
#                                             Geometry    N_SQ_AD  N_VOIE  \
# 0  {"coordinates": [2.385363237327124, 48.8681499...  750088825    31.0
# 1  {"coordinates": [2.308770442174867, 48.8739182...  750038510     2.0
# 2  {"coordinates": [2.34848334292492, 48.84631684...  750162012    14.0
# 3  {"coordinates": [2.3857899214565674, 48.850519...  750054032    31.0
# 4  {"coordinates": [2.2684341614185204, 48.852335...  750128612    47.0
#
#   C_SUF1 C_SUF2 C_SUF3  C_AR  A_NVOIE B_ANGLE B_OFFSTDF B_AFFSTDF B_HORS75  \
# 0    NaN    NaN    NaN  20.0     21.0       N         O       NaN        N
# 1    NaN    NaN    NaN   8.0    222.0       O         O       NaN        N
# 2    NaN    NaN    NaN   5.0    346.0       N         O       NaN        N
# 3      b    NaN    NaN  11.0    359.0       N         O       NaN        N
# 4    NaN    NaN    NaN  16.0    124.0       O         O       NaN        N
#
#   L_NVOIE                 L_ADR      N_SQ_AR      N_SQ_VO  OBJECTID
# 0      31  31 RUE ETIENNE DOLET  750000020.0  750003581.0     48975
# 1       2    2 RUE PAUL CEZANNE  750000008.0  750004449.0     48990
# 2      14         14 RUE CLOVIS  750000005.0  750004930.0     49022
# 3     31b  31b RUE DE MONTREUIL  750000011.0  750003059.0     49026
# 4      47         47 RUE RIBERA  750000016.0  750000897.0     49033

# %%
adresses[["Numéro", "Rue"]] = adresses["L_ADR"].str.split(" ", 1, expand=True)
adresses["Rue"] = adresses["Rue"].str.lower()
adresses.head()
# Out:
#                             Geometry X Y  \
# 0   48.868149964330925,2.385363237327124
# 1   48.873918224142145,2.308770442174867
# 2     48.84631684220949,2.34848334292492
# 3  48.850519497345935,2.3857899214565674
# 4   48.85233571571768,2.2684341614185204
#
#                                             Geometry    N_SQ_AD  N_VOIE  \
# 0  {"coordinates": [2.385363237327124, 48.8681499...  750088825    31.0
# 1  {"coordinates": [2.308770442174867, 48.8739182...  750038510     2.0
# 2  {"coordinates": [2.34848334292492, 48.84631684...  750162012    14.0
# 3  {"coordinates": [2.3857899214565674, 48.850519...  750054032    31.0
# 4  {"coordinates": [2.2684341614185204, 48.852335...  750128612    47.0
#
#   C_SUF1 C_SUF2 C_SUF3  C_AR  A_NVOIE B_ANGLE B_OFFSTDF B_AFFSTDF B_HORS75  \
# 0    NaN    NaN    NaN  20.0     21.0       N         O       NaN        N
# 1    NaN    NaN    NaN   8.0    222.0       O         O       NaN        N
# 2    NaN    NaN    NaN   5.0    346.0       N         O       NaN        N
# 3      b    NaN    NaN  11.0    359.0       N         O       NaN        N
# 4    NaN    NaN    NaN  16.0    124.0       O         O       NaN        N
#
#   L_NVOIE                 L_ADR      N_SQ_AR      N_SQ_VO  OBJECTID Numéro  \
# 0      31  31 RUE ETIENNE DOLET  750000020.0  750003581.0     48975     31
# 1       2    2 RUE PAUL CEZANNE  750000008.0  750004449.0     48990      2
# 2      14         14 RUE CLOVIS  750000005.0  750004930.0     49022     14
# 3     31b  31b RUE DE MONTREUIL  750000011.0  750003059.0     49026    31b
# 4      47         47 RUE RIBERA  750000016.0  750000897.0     49033     47
#
#                  Rue
# 0  rue etienne dolet
# 1   rue paul cezanne
# 2         rue clovis
# 3   rue de montreuil
# 4         rue ribera
