# %% [markdown]
# # Alignment Functions

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import re
from collections import Counter
from tqdm import tqdm

# %% [markdown]
# #### Importing Data

# %%
bottins = pd.read_csv("data/strict_addressing.csv")
voies = pd.read_csv("data/opendata_voie_paris.csv", sep=";")
#keep only columns that might be useful further on
voies = voies[["N_SQ_VO", "L_VOIE", "L_COURTMIN", "L_LONGMIN", "Geometry", "LENGTH", "Geometry X Y"]]

# %% [markdown]
# ## conservative

# %%
def align_on_column(df_not_aligned, df_streets, df_aligned=pd.DataFrame(), mergeOnLeft="Rue", mergeOnRight=["L_VOIE"]):
    # make copies to avoid alteration of source dataframes
    not_aligned = df_not_aligned.copy()
    streets = df_streets.copy()
    if not df_aligned.empty:
        aligned = df_aligned.copy()
    else:
        aligned = df_aligned
        
    for rkey in mergeOnRight:
        # format to make match possible
        streets[rkey] = streets[rkey].str.lower()
        not_aligned[mergeOnLeft] = not_aligned[mergeOnLeft].str.lower()
        # merge
        merged = not_aligned.merge(streets, how="left", left_on=mergeOnLeft, right_on=rkey, suffixes=(False, False))
        # append newly aligned cases to aligned dataframe
        newly_aligned = merged[merged[rkey].notna()]
        # add column to know what alignment was on
        newly_aligned["aligned_on"] = rkey
        aligned = pd.concat([aligned, newly_aligned])
        
        # update not aligned rows
        not_aligned = merged[merged[rkey].isna()]
        not_aligned = not_aligned.drop(list(streets.columns), axis=1)
        print(f"Joining on {rkey}\n#total aligned: {len(aligned)}, newly aligned: {len(newly_aligned)}, not aligned: {len(not_aligned)}")
    
    return aligned, not_aligned

# %%
aligned, not_aligned = align_on_column(bottins, voies, mergeOnRight=["L_VOIE", "L_COURTMIN", "L_LONGMIN"])
# Out:
# C:\Users\Lea\AppData\Local\Temp/ipykernel_18168/831735043.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newly_aligned["aligned_on"] = rkey
# Joining on L_VOIE
# #total aligned: 1933426, newly aligned: 1933426, not aligned: 3191199
# Joining on L_COURTMIN
# #total aligned: 2545967, newly aligned: 612541, not aligned: 2578666
# Joining on L_LONGMIN
# #total aligned: 2713723, newly aligned: 167756, not aligned: 2410910

# %% [markdown]
# ## substituting accents (characters in general)

# %%
# function to replace different characters at once in a string, based on a dictionary
def replace_chars_by_dict(string, map_dict):
    #https://www.geeksforgeeks.org/python-replace-different-characters-in-string-at-once/
    return re.compile("|".join(map_dict.keys())).sub(lambda ele: map_dict[re.escape(ele.group(0))], string)

def substitute_on_streets_and_align(df_not_aligned, df_streets, map_dict, df_aligned=pd.DataFrame(), mergeOnLeft="Rue", mergeOnRight=["L_VOIE"]):
    streets = df_streets.copy()
    mergeOnRight_new = list()
    for rkey in mergeOnRight:
        rkey_new = f"{rkey}_new"
        streets[rkey_new] = streets[rkey].apply(replace_chars_by_dict, args=(map_dict,))
        mergeOnRight_new.append(rkey_new)
    
    aligned, not_aligned = align_on_column(df_not_aligned=df_not_aligned, df_streets=streets, df_aligned=df_aligned, mergeOnLeft=mergeOnLeft, mergeOnRight=mergeOnRight_new)
    aligned = aligned.drop(mergeOnRight_new, axis=1)
    return aligned, not_aligned

# %%
dict_accents = {"é": "e", "è": "e", "ê":"e", "à":"a", "â":"a", "ô":"o", "î":"i", "û":"u"}
aligned, not_aligned = substitute_on_streets_and_align(df_not_aligned=not_aligned, df_streets=voies, 
                                                                 map_dict=dict_accents, df_aligned=aligned,
                                                                mergeOnRight=["L_VOIE", "L_COURTMIN", "L_LONGMIN"])
# Out:
# Joining on L_VOIE_new
# #total aligned: 2713723, newly aligned: 0, not aligned: 2410910
# C:\Users\Lea\AppData\Local\Temp/ipykernel_10528/831735043.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newly_aligned["aligned_on"] = rkey
# Joining on L_COURTMIN_new
# #total aligned: 2718069, newly aligned: 4346, not aligned: 2406564
# Joining on L_LONGMIN_new
# #total aligned: 2718972, newly aligned: 903, not aligned: 2405661

# %% [markdown]
# ## substituting spaces and .-

# %%
not_aligned["no_spaces"] = not_aligned["Rue"].str.replace(".", "", regex=False)
not_aligned["no_spaces"] = not_aligned["no_spaces"].str.replace(" ", "", regex=False)
not_aligned["no_spaces"] = not_aligned["no_spaces"].str.replace("-", "", regex=False)

# %%
voies_copy = voies.copy()
voies_copy["no_spaces_long"] = voies_copy["L_LONGMIN"].str.replace(".", "", regex=False)
voies_copy["no_spaces_long"] = voies_copy["no_spaces_long"].str.replace(" ", "", regex=False)
voies_copy["no_spaces_long"] = voies_copy["no_spaces_long"].str.replace("-", "", regex=False)

# %%
aligned, not_aligned = align_on_column(not_aligned, voies_copy, aligned, mergeOnLeft="no_spaces", mergeOnRight=["no_spaces_long"])
# Out:
# C:\Users\Lea\AppData\Local\Temp/ipykernel_10528/831735043.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newly_aligned["aligned_on"] = rkey
# Joining on no_spaces_long
# #total aligned: 2747447, newly aligned: 28475, not aligned: 2377194

# %%
voies_copy = voies.copy()
voies_copy["no_spaces_court"] = voies_copy["L_COURTMIN"].str.replace(".", "", regex=False)
voies_copy["no_spaces_court"] = voies_copy["no_spaces_court"].str.replace(" ", "", regex=False)
voies_copy["no_spaces_court"] = voies_copy["no_spaces_court"].str.replace("-", "", regex=False)
aligned, not_aligned = align_on_column(not_aligned, voies_copy, aligned, mergeOnLeft="no_spaces", mergeOnRight=["no_spaces_court"])
# Out:
# C:\Users\Lea\AppData\Local\Temp/ipykernel_10528/831735043.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newly_aligned["aligned_on"] = rkey
# Joining on no_spaces_court
# #total aligned: 2856095, newly aligned: 108648, not aligned: 2268694

# %%
aligned.tail()
# Out:
#             Unnamed: 0  page  row              Nom        Métier  \
# 2377325  bpt6k9780089g  1607  192  Zullig (Arnold)      fourreur
# 2377326  bpt6k9780089g  1607  194          Zuloaga  peintre-art.
# 2377334  bpt6k9780089g  1607  227      Zusman (S.)       meubles
# 2377336  bpt6k9780089g  1607  233           Zutter   électricité
# 2377337  bpt6k9780089g  1607  235            Zvang    blanchiss.
#
#                                Rue Numéro  annee      N_SQ_VO  \
# 2377325  r. croix-des-petitschamps    33.   1922  750005891.0
# 2377326             r.caulaincourt    54.   1922  750006458.0
# 2377334            r. joseph-dijon    16.   1922  750003300.0
# 2377336     av. de la grande-armée    85.   1922  750001383.0
# 2377337            r. jules-vallès     5.   1922  750003237.0
#
#                           L_VOIE                  L_COURTMIN  \
# 2377325  CROIX DES PETITS CHAMPS  R. Croix des Petits Champs
# 2377326             CAULAINCOURT             R. Caulaincourt
# 2377334             JOSEPH DIJON             R. Joseph Dijon
# 2377336             GRANDE ARMEE      Av. de la Grande Armée
# 2377337             JULES VALLES             R. Jules Vallès
#
#                            L_LONGMIN  \
# 2377325  Rue Croix des Petits Champs
# 2377326             Rue Caulaincourt
# 2377334             Rue Joseph Dijon
# 2377336    Avenue de la Grande Armée
# 2377337             Rue Jules Vallès
#
#                                                   Geometry       LENGTH  \
# 2377325  {"coordinates": [[2.339184280672447, 48.862218...   395.247666
# 2377326  {"coordinates": [[[2.3295839496506456, 48.8846...  1377.350313
# 2377334  {"coordinates": [[2.34789895265875, 48.8936934...   199.038155
# 2377336  {"coordinates": [[[2.294022093593509, 48.87410...   944.223697
# 2377337  {"coordinates": [[2.385126163672793, 48.852695...   213.882502
#
#                                   Geometry X Y       aligned_on  \
# 2377325   48.863930647003784,2.340033235528675  no_spaces_court
# 2377326   48.888012381700015,2.335330632931254  no_spaces_court
# 2377334  48.893993137898086,2.3466298590464247  no_spaces_court
# 2377336    48.87588684710302,2.288398613762114  no_spaces_court
# 2377337   48.853659996235805,2.385053516055706  no_spaces_court
#
#                      no_spaces no_spaces_long        no_spaces_court
# 2377325  rcroixdespetitschamps            NaN  rcroixdespetitschamps
# 2377326          rcaulaincourt            NaN          rcaulaincourt
# 2377334           rjosephdijon            NaN           rjosephdijon
# 2377336      avdelagrandearmée            NaN      avdelagrandearmée
# 2377337           rjulesvallès            NaN           rjulesvallès

# %% [markdown]
# ## intermediary statistics

# %%
#showing that there are still a lot of streets to match
print("streets matched:", len(aligned["Rue"].unique()), "streets not matched:", len(not_aligned["Rue"].unique()))
# Out:
# 16203 174827

# %%
#a lot of frequent streets are not matched yet!
Counter(not_aligned["Rue"]).most_common(200)
# Out:
# [('st-honoré', 29537),
#  ('st-denis', 29477),
#  ('st-martin', 25716),
#  ('faub.-st-martin', 19295),
#  ('faub.-st-antoine', 18336),
#  ('faub.-st-denis', 17799),
#  ('boul. voltaire', 16675),
#  ('st-jacques', 13365),
#  ('lafayette', 12842),
#  ('boul. sébastopol', 12819),
#  ('faub.-st-honoré', 12452),
#  ('st-antoine', 12158),
#  ('sèvres', 11995),
#  ('st-lazare', 11802),
#  ('faub.-poissonnière', 11485),
#  ('boul. beaumarchais', 11236),
#  ('boul. magenta', 11227),
#  ('faub.-du-temple', 11038),
#  ('boul. st-germain', 10978),
#  ('cléry', 9850),
#  ('vieille-du-temple', 9038),
#  ('boul. haussmann', 8868),
#  ('bondy', 8713),
#  ('université', 8549),
#  ('boul. malesherbes', 8458),
#  ('ste-anne', 8297),
#  ('ménilmontant', 8098),
#  ('faub.-montmartre', 8032),
#  ('st-dominique', 7994),
#  ('grenelle-st-germain', 7946),
#  ('boul. st-michel', 7794),
#  ('st-maur', 7391),
#  ('boul. de la villette', 6984),
#  ('boul. de strasbourg', 6966),
#  ('boul. du temple', 6875),
#  ('allemagne', 6736),
#  ('st-sauveur', 6645),
#  ('aumaire', 6354),
#  ('boul. montparnasse', 5976),
#  ('rochechouart', 5863),
#  ('n.-d.-de-nazareth', 5822),
#  ('réaumur', 5576),
#  ('r. st-honoré', 5429),
#  ('boul. des italiens', 5392),
#  ('boul. st-martin', 5342),
#  ('boul. poissonnière', 5319),
#  ("chaussée-d'antin", 5295),
#  ('quai jemmapes', 5174),
#  ('michel-le-comte', 5002),
#  ('coquillière', 4987),
#  ('sts-pères', 4813),
#  ('petites-ecuries', 4721),
#  ('r. de flandre', 4571),
#  ('r. st-denis', 4565),
#  ('r. st-maur', 4557),
#  ('poissonnière', 4552),
#  ('jeûneurs', 4512),
#  ('st-marc', 4502),
#  ('miroménil', 4383),
#  ('boul. de clichy', 4369),
#  ('paradis-poissonnière', 4334),
#  ('boul. bonne-nouvelle', 4322),
#  ('folie-méricourt', 4276),
#  ('trévise', 4240),
#  ('boul. richard-lenoir', 4111),
#  ('r. st-martin', 4022),
#  ('chemin-vert', 3970),
#  ('st-victor', 3923),
#  ('st-louis-marais', 3884),
#  ('monsieur-le-prince', 3867),
#  ('faub. poissonnière', 3852),
#  ('boul. de la gare', 3820),
#  ('faub. st-denis', 3770),
#  ('faub. st-martin', 3767),
#  ("château-d'eau", 3760),
#  ('pépinière', 3752),
#  ('thévenot', 3743),
#  ('bourbon-villeneuve', 3710),
#  ('fontaine-au-roi', 3701),
#  ('boul. st-denis', 3632),
#  ('faub. st-antoine', 3612),
#  ("boul. de l'hôpital", 3610),
#  ('arbre-sec', 3588),
#  ('st-maur-popincourt', 3531),
#  ('boul. des batignolles', 3498),
#  ('michodière', 3491),
#  ('blancs-manteaux', 3488),
#  ('j.-j.-rousseau', 3472),
#  ('boul. des capucines', 3419),
#  ('quai valmy', 3365),
#  ('st-sébastien', 3362),
#  ('bergère', 3354),
#  ('grenier-st-lazare', 3334),
#  ('st-paul', 3325),
#  ('boul. montmartre', 3316),
#  ('boul. de belleville', 3242),
#  ('st-georges', 3237),
#  ('louis-le-grand', 3233),
#  ('ecole-de-médecine', 3221),
#  ('nve-st-augustin', 3163),
#  ('four-st-germain', 3140),
#  ('nve-des-petits-champs', 3101),
#  ('trois-bornes', 3093),
#  ('faub. st-honoré', 3082),
#  ('marché-st-honoré', 3049),
#  ('boul. ménilmontant', 3037),
#  ('grammont', 3018),
#  ('grenétat', 3010),
#  ('odéon', 3002),
#  ("avenue d'orléans", 2987),
#  ('r. st-lazare', 2986),
#  ('boul. barbès', 2861),
#  ('boul. rochechouart', 2853),
#  ('petit-carreau', 2840),
#  ('traversière', 2839),
#  ('vanves', 2790),
#  ('boul. diderot', 2781),
#  ('albouy', 2766),
#  ('vieux-augustins', 2766),
#  ('glacière', 2757),
#  ('bons-enfants', 2743),
#  ('châteaudun', 2684),
#  ('n.-d.-de-lorette', 2658),
#  ('r. st-jacques', 2643),
#  ('croix-des-petits-champs', 2595),
#  ('st-roch', 2590),
#  ('st-andré-des-arts', 2565),
#  ("r. d'allemagne", 2560),
#  ('boul. ornano', 2556),
#  ('grange-batelière', 2555),
#  ('boul. de la chapelle', 2504),
#  ('la harpe', 2501),
#  ("r. d'angoulême", 2456),
#  ('faub. du temple', 2455),
#  ('colisée', 2439),
#  ('grenéta', 2412),
#  ('boul. de courcelles', 2396),
#  ("av. d'orléans", 2387),
#  ('grenelle-st-honoré', 2369),
#  ('cité trévise', 2361),
#  ('mont-thabor', 2352),
#  ('guénégaud', 2351),
#  ('francs-bourgeois', 2337),
#  ('fontaine-st-georges', 2333),
#  ('boul. de grenelle', 2318),
#  ('chaussée-d’antin', 2278),
#  ('boul. de charonne', 2277),
#  ('grange-aux-belles', 2273),
#  ('vieux-colombier', 2269),
#  ('filles-du-calvaire', 2232),
#  ('r. de vanves', 2219),
#  ("bourg-l'abbé", 2215),
#  ('phélippeaux', 2204),
#  ('aux ours', 2170),
#  ('ancienne-comédie', 2140),
#  ('corbeau', 2138),
#  ('simon-le-franc', 2124),
#  ('taranne', 2115),
#  ('bellefond', 2111),
#  ("st-louis-en-l'ile", 2108),
#  ('roi-de-sicile', 2101),
#  ('grande-truanderie', 2091),
#  ('r. st-antoine', 2084),
#  ('luxembourg', 2081),
#  ('cardinal-lemoine', 2067),
#  ('st-placide', 2062),
#  ('nve-des-mathurins', 2060),
#  ('noyers', 2054),
#  ('commerce-grenelle', 2053),
#  ('faub. montmartre', 2051),
#  ('godot', 2049),
#  ('dames-batignolles', 2031),
#  ('boul. st-marcel', 2031),
#  ('boul. arago', 2018),
#  ('r. de bondy', 2016),
#  ('r. st-dominique', 2002),
#  ('angoulême-du-temple', 1994),
#  ('croix-nivert', 1994),
#  ('marais-st-martin', 1971),
#  ('st-sulpice', 1953),
#  ('vanneau', 1952),
#  ('rue st-honoré', 1937),
#  ('crimée', 1923),
#  ('sourdière', 1920),
#  ('faub.-stmartin', 1918),
#  ('fontaine-molière', 1913),
#  ('basse-du-rempart', 1880),
#  ('av. de st-ouen', 1878),
#  ('boul. péreire', 1868),
#  ('n.-d.-des-victoires', 1849),
#  ('quatre-fils', 1824),
#  ('breda', 1800),
#  ('petits-champs', 1797),
#  ('st-sabin', 1790),
#  ('vendôme', 1787),
#  ('stdenis', 1778),
#  ('berlin', 1776),
#  ('angoulême', 1767),
#  ('sévigné', 1755),
#  ('fidélité', 1725)]

# %%
# this is also the case for streets from 1883 on, when Paris was already remodelled -> old map data won't help
not_aligned.iloc[-1000000] #1883
Counter(not_aligned[-100000:]["Rue"]).most_common(10)
# Out:
# [('boul. voltaire', 1475),
#  ('r. st-honoré', 1248),
#  ('faub. poissonnière', 1205),
#  ('faub. st-antoine', 1152),
#  ('faub. st-denis', 1130),
#  ('r. st-maur', 1102),
#  ('faub. st-martin', 1040),
#  ('r. st-denis', 1020),
#  ('boul. st-germain', 1012),
#  ('r. de flandre', 986)]

# %%
#statistics about how often the least frequent streets appear in the not_aligned data
counted_rues = Counter(not_aligned["Rue"])
Counter(counted_rues.values()).most_common(10) #-> 121746 street names appear only once, 19080 only twice etc.
# Out:
# [(1, 121746),
#  (2, 19080),
#  (3, 8284),
#  (4, 4698),
#  (5, 3088),
#  (6, 2234),
#  (7, 1549),
#  (8, 1217),
#  (9, 1011),
#  (10, 854)]

# %% [markdown]
# ## creating a list of most common prefixes and aligning without them

# %%
#get street names of not_aligned data
rue_names = list(counted_rues.keys())

# %%
#if there is a space or a "-" in the name, match everything before it (greedy matching)
def match_prefix(street):
    result = re.match(r".*[ -]", street)
    if result:
        return result.group()
    else:
        return ""

# %%
match_prefix(rue_names[0])
# Out:
# 'passage '

# %%
# get all the prefixes with the above defined function
prefixes = [match_prefix(street) for street in rue_names[:17827]] 
Counter(prefixes).most_common(100)
# Out:
# [('', 3208),
#  ('st-', 265),
#  ('pass. ', 99),
#  ('nve-', 91),
#  ('et ', 87),
#  ('neuve-', 75),
#  ('faub.-', 70),
#  ('ste-', 64),
#  ('boul. ', 60),
#  ('passage ', 58),
#  ('nve-st-', 54),
#  ('place ', 52),
#  ('nye-', 49),
#  ('faub.-st-', 45),
#  ('quai ', 45),
#  ('q. ', 42),
#  ('petit-', 35),
#  ('nve-des-', 33),
#  ('pl. ', 32),
#  ('saint-', 31),
#  ('avenue ', 31),
#  ('trois-', 30),
#  ('grenelle-st-', 30),
#  ('boul. des ', 29),
#  ('vieille-', 29),
#  ('geoffroy-', 29),
#  ('faub. -', 29),
#  ('faub. ', 28),
#  ('four-st-', 28),
#  ('faub. -st-', 27),
#  ('impasse ', 27),
#  ('nye-st-', 26),
#  ('neuve-st-', 26),
#  ('boulev. ', 25),
#  ('cité ', 23),
#  ('st-maur-', 22),
#  ('chaussée-', 22),
#  ('fossés-', 22),
#  ('si-', 22),
#  ('vieux-', 21),
#  ('st. ', 21),
#  ('marché-', 21),
#  ('rue ', 21),
#  ('imp. ', 21),
#  ('grand-', 20),
#  ('st ', 20),
#  ('paradis-', 19),
#  ('q. de ', 19),
#  ('pass. du ', 19),
#  ('petits-', 19),
#  ('bourbon-', 18),
#  ('cour ', 18),
#  ('deux-', 18),
#  ('quai de ', 18),
#  ('· ', 18),
#  ('grande-', 18),
#  ('st-louis-', 17),
#  ('faub.-du-', 17),
#  ('st-germain-', 17),
#  ('grange-', 17),
#  ('fontaine-', 17),
#  ('neuve-des-', 17),
#  ('boul. de ', 16),
#  ('q. de la ', 16),
#  ('jean-', 16),
#  ('pl. st-', 16),
#  ('pass. des ', 16),
#  ('notre-dame-de-', 15),
#  ('petites-', 15),
#  ('vieille-du-', 15),
#  ('st-nicolas-', 15),
#  ('faubourg-', 15),
#  ('quai de la ', 15),
#  ('notre-dame-', 15),
#  ('quai des ', 14),
#  ('boul. st-', 14),
#  ('amandiers-', 14),
#  ('faub. st-', 14),
#  ('la ', 14),
#  ('pierre-', 14),
#  ('anjou-', 14),
#  ('faub. - ', 14),
#  ('q. des ', 14),
#  ('fossés-st-', 14),
#  ('nvest-', 14),
#  ('nyest-', 14),
#  ('passage st-', 14),
#  ('marais-', 14),
#  ('gal. ', 14),
#  ('neuvest-', 13),
#  ('nve-ste-', 13),
#  ('nve-de-', 13),
#  ('petite-', 13),
#  ('cloître-st-', 13),
#  ('n.-d.-de-', 13),
#  ('royale-st-', 13),
#  ('culture-ste-', 13),
#  ('pl. du ', 13),
#  ('nre-', 13),
#  ('nre-st-', 13)]

# %%
# take 300 most common prefixes (appearing down to 5 or 6 times in data)
most_common_prefixes = list(zip(*Counter(prefixes).most_common(300)))[0]
# convert to list and delete the empty entry
most_common_prefixes = list(most_common_prefixes)[1:]
most_common_prefixes
# Out:
# ['st-',
#  'pass. ',
#  'nve-',
#  'et ',
#  'neuve-',
#  'faub.-',
#  'ste-',
#  'boul. ',
#  'passage ',
#  'nve-st-',
#  'place ',
#  'nye-',
#  'faub.-st-',
#  'quai ',
#  'q. ',
#  'petit-',
#  'nve-des-',
#  'pl. ',
#  'saint-',
#  'avenue ',
#  'trois-',
#  'grenelle-st-',
#  'boul. des ',
#  'vieille-',
#  'geoffroy-',
#  'faub. -',
#  'faub. ',
#  'four-st-',
#  'faub. -st-',
#  'impasse ',
#  'nye-st-',
#  'neuve-st-',
#  'boulev. ',
#  'cité ',
#  'st-maur-',
#  'chaussée-',
#  'fossés-',
#  'si-',
#  'vieux-',
#  'st. ',
#  'marché-',
#  'rue ',
#  'imp. ',
#  'grand-',
#  'st ',
#  'paradis-',
#  'q. de ',
#  'pass. du ',
#  'petits-',
#  'bourbon-',
#  'cour ',
#  'deux-',
#  'quai de ',
#  '· ',
#  'grande-',
#  'st-louis-',
#  'faub.-du-',
#  'st-germain-',
#  'grange-',
#  'fontaine-',
#  'neuve-des-',
#  'boul. de ',
#  'q. de la ',
#  'jean-',
#  'pl. st-',
#  'pass. des ',
#  'notre-dame-de-',
#  'petites-',
#  'vieille-du-',
#  'st-nicolas-',
#  'faubourg-',
#  'quai de la ',
#  'notre-dame-',
#  'quai des ',
#  'boul. st-',
#  'amandiers-',
#  'faub. st-',
#  'la ',
#  'pierre-',
#  'anjou-',
#  'faub. - ',
#  'q. des ',
#  'fossés-st-',
#  'nvest-',
#  'nyest-',
#  'passage st-',
#  'marais-',
#  'gal. ',
#  'neuvest-',
#  'nve-ste-',
#  'nve-de-',
#  'petite-',
#  'cloître-st-',
#  'n.-d.-de-',
#  'royale-st-',
#  'culture-ste-',
#  'pl. du ',
#  'nre-',
#  'nre-st-',
#  '9. ',
#  'nye-des-',
#  'basse-du-',
#  'aux ',
#  'chemin de ronde de la barrière ',
#  'marais-st-',
#  'place st-',
#  'marché-st-',
#  'st-pierre-',
#  'bourg-',
#  'grenelle-',
#  'ville-',
#  'grands-',
#  'montagne-ste-',
#  'de ',
#  'st-louis-en-',
#  'gr.-',
#  'neuve-saint-',
#  'avenue de ',
#  'bouley. ',
#  'croix-des-',
#  'pavée-st-',
#  'st.-',
#  'faub-',
#  'boul. bonne-',
#  'j.-j.-',
#  'cloître st-',
#  'cloître-',
#  'marché-aux-',
#  'pass. st-',
#  'place de la ',
#  'cloître-st-jacques-',
#  'ecole-de-',
#  'bons-',
#  'aven. ',
#  'mont-',
#  'deux-portes-',
#  'st-germ.-',
#  'quatre-',
#  'nre-des-',
#  'vieilles-',
#  'pass. de ',
#  'boul. de la ',
#  'petit-lion-st-',
#  'deux-portes-st-',
#  'neuve-de-',
#  'impasse st-',
#  's:-',
#  'cimetière-st-',
#  'pl. de ',
#  'orléans-st-',
#  'passage de ',
#  'st-andré-des-',
#  'f.-st-',
#  'vieilles-etuves-st-',
#  'francs-bourgeois-',
#  'faub -',
#  'contrescarpe-',
#  'st-andré-',
#  'faub.st-',
#  'traversière-st-',
#  'coq-',
#  'ste-marguerite-st-',
#  'n.-d.-',
#  'galerie ',
#  'four-',
#  'taub.-',
#  'pass. de la ',
#  'orléans-',
#  'st-hyacinthe-st-',
#  'st - ',
#  'place du ',
#  'royale-',
#  'angoulême-',
#  'des ',
#  'sainte-',
#  'croix-',
#  'cloitre-st-',
#  'cloitre st-',
#  'nye-ste-',
#  'st-jean-de-',
#  'nve-des-petits-',
#  'royale st-',
#  'monsieur-le-',
#  'grange-aux-',
#  'n.-d.-des-',
#  'arbre-',
#  'faub-st-',
#  'filles-st-',
#  'filles-',
#  'imp. st-',
#  'ste-croix-',
#  'et st-',
#  'lavandières-st-',
#  'faub. - st-',
#  'faub -st-',
#  'cour de la ',
#  'ferme-des-',
#  'nyc-st-',
#  'st-dominique-st-',
#  'pl. de la ',
#  'tour-',
#  'gren.-st-',
#  'pavée-',
#  'renard-',
#  'boul ',
#  'prêtres-st-',
#  'nye-de-',
#  'de la ',
#  'fossés-st-germ.-',
#  'cloître ',
#  'st-dominique-',
#  'ne-st-',
#  'r. ',
#  'sts-',
#  'fossés-du-',
#  'enfants-',
#  'boul. du ',
#  'champs-',
#  'cour des ',
#  'st-thomas-',
#  'basse-',
#  'fontaines-',
#  'n.-d. -',
#  'blancs-',
#  'guérin-',
#  'notre-damede-',
#  'filles-du-',
#  'ancienne-',
#  'faubourg-st-',
#  'impasse de la ',
#  'château-',
#  'renard-st-',
#  'fossés-saint-',
#  'delta-',
#  'n.-dame-de-',
#  'louis-',
#  'prêtres-st-germain-',
#  'faub. -du-',
#  'ste-croix-de-la-',
#  'fanb.-st-',
#  'fb.-st-',
#  'ste-croix-la-',
#  'traversière-',
#  'croix-du-',
#  'fourcy-st-',
#  'pet.-',
#  'boulev. de ',
#  'taub.-st-',
#  'angoulème-',
#  'puits-',
#  'fossés-st-germain-',
#  'passage du ',
#  'contrescarpe-st-',
#  'valois-',
#  'place de ',
#  'plâtre-',
#  'impasse de ',
#  'cherche-',
#  'avenue des ',
#  '. ',
#  'boucherie-des-',
#  'st-hyacinthe-',
#  'rue de ',
#  'nve-de-la-',
#  's.-',
#  'neuve-ste-',
#  'cloîtrest-',
#  'pass ',
#  'neure-',
#  'nve. st-',
#  'fauh.-',
#  'fossés-st-germ. -',
#  '$t-',
#  'st-thomas-du-',
#  'nve-du-',
#  'cimetière-',
#  'cl. st-',
#  'galer. ',
#  'nve st-',
#  'sie-',
#  'nvc-',
#  'nvc-st-',
#  'pass. ste-',
#  'angoulème-du-',
#  'cour du ',
#  'lavandières-ste-',
#  'faub.-st ',
#  'nve-des-bons-',
#  'angoulême-du-',
#  'pl. du marché-',
#  '9. des ',
#  'en ',
#  'place du marché-',
#  'boul.-',
#  'beaujolais-',
#  'faub.- st-',
#  'faubourg-saint-',
#  'imp. des ',
#  'faub.-saint-']

# %%
#creating new column "sans_pref" in not_aligned data, where all prefixes are deleted
not_aligned["sans_pref"] = not_aligned['Rue']
for prefix in tqdm(most_common_prefixes):
    not_aligned["sans_pref"] = not_aligned["sans_pref"].str.replace(prefix, "", regex=False)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 299/299 [10:08<00:00,  2.04s/it]

# %%
#aligning on this new column (sans_pref)
aligned, not_aligned = align_on_column(not_aligned, voies, aligned, mergeOnLeft="sans_pref", mergeOnRight=["L_VOIE", "L_COURTMIN", "L_LONGMIN"])
# Out:
# C:\Users\Lea\AppData\Local\Temp/ipykernel_10528/831735043.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newly_aligned["aligned_on"] = rkey
# Joining on L_VOIE
# #total aligned: 3558483, newly aligned: 702388, not aligned: 1948817
# Joining on L_COURTMIN
# #total aligned: 3558483, newly aligned: 0, not aligned: 1948817
# Joining on L_LONGMIN
# #total aligned: 3558485, newly aligned: 2, not aligned: 1948815

# %%
aligned.tail(50)
# Out:
#             Unnamed: 0  page  row                   Nom  \
# 2651104  bpt6k9780089g  1606   61            Zelikoswki
# 2651105  bpt6k9780089g  1606   63         Zelinsky (L.)
# 2651106  bpt6k9780089g  1606   63         Zelinsky (L.)
# 2651107  bpt6k9780089g  1606   63         Zelinsky (L.)
# 2651108  bpt6k9780089g  1606   63         Zelinsky (L.)
# 2651109  bpt6k9780089g  1606   63         Zelinsky (L.)
# 2651110  bpt6k9780089g  1606   63         Zelinsky (L.)
# 2651111  bpt6k9780089g  1606   63         Zelinsky (L.)
# 2651115  bpt6k9780089g  1606   97                 Zēmor
# 2651116  bpt6k9780089g  1606   97                 Zēmor
# 2651118  bpt6k9780089g  1606  109           Zender fils
# 2651119  bpt6k9780089g  1606  109           Zender fils
# 2651120  bpt6k9780089g  1606  109           Zender fils
# 2651121  bpt6k9780089g  1606  109           Zender fils
# 2651123  bpt6k9780089g  1606  132           Zenner (P.)
# 2651125  bpt6k9780089g  1606  162             Zerr (A.)
# 2651126  bpt6k9780089g  1606  175                 Zeude
# 2651131  bpt6k9780089g  1606  202               Ziefman
# 2651132  bpt6k9780089g  1606  202               Ziefman
# 2651133  bpt6k9780089g  1606  204           Ziegel (G.)
# 2651134  bpt6k9780089g  1606  204           Ziegel (G.)
# 2651135  bpt6k9780089g  1606  204           Ziegel (G.)
# 2651137  bpt6k9780089g  1606  212               Ziegler
# 2651138  bpt6k9780089g  1606  212               Ziegler
# 2651139  bpt6k9780089g  1606  212               Ziegler
# 2651140  bpt6k9780089g  1606  223  Ziegler de Loës (P.)
# 2651141  bpt6k9780089g  1606  223  Ziegler de Loës (P.)
# 2651145  bpt6k9780089g  1606  264              Zimbacca
# 2651147  bpt6k9780089g  1606  288                Zimmer
# 2651149  bpt6k9780089g  1606  294  Zimmerlé et Veillrot
# 2651157  bpt6k9780089g  1606  334            Zimmermann
# 2651160  bpt6k9780089g  1607    6                 Zipcy
# 2651164  bpt6k9780089g  1607   18           Zirwès (A.)
# 2651165  bpt6k9780089g  1607   18           Zirwès (A.)
# 2651166  bpt6k9780089g  1607   18           Zirwès (A.)
# 2651167  bpt6k9780089g  1607   18           Zirwès (A.)
# 2651168  bpt6k9780089g  1607   18           Zirwès (A.)
# 2651171  bpt6k9780089g  1607   31               Zismann
# 2651172  bpt6k9780089g  1607   31               Zismann
# 2651176  bpt6k9780089g  1607   51           Zivy (Paul)
# 2651179  bpt6k9780089g  1607   90             Zola (L.)
# 2651180  bpt6k9780089g  1607   90             Zola (L.)
# 2651185  bpt6k9780089g  1607  130            Zuber (C.)
# 2651186  bpt6k9780089g  1607  130            Zuber (C.)
# 2651189  bpt6k9780089g  1607  152             Zucherini
# 2651194  bpt6k9780089g  1607  204           Zupkes (H.)
# 2651195  bpt6k9780089g  1607  204           Zupkes (H.)
# 2651202  bpt6k9780089g  1607  252              Zwilling
# 7603     bpt6k6282019m   223  119                 Conté
# 1884443  bpt6k9776121t   917  105             Wagenheim
#
#                            Métier                      Rue       Numéro  \
# 2651104                   meubles           boul. voltaire          30.
# 2651105       tailleur pour dames     boul. de la chapelle         118.
# 2651106       tailleur pour dames     boul. de la chapelle         118.
# 2651107       tailleur pour dames     boul. de la chapelle         118.
# 2651108       tailleur pour dames     boul. de la chapelle         118.
# 2651109       tailleur pour dames     boul. de la chapelle         118.
# 2651110       tailleur pour dames     boul. de la chapelle         118.
# 2651111       tailleur pour dames     boul. de la chapelle         118.
# 2651115                 publicite       boul. des italiens           8.
# 2651116                 publicite       boul. des italiens           8.
# 2651118                 serrurier     boul. de la villette         168.
# 2651119                 serrurier     boul. de la villette         168.
# 2651120                 serrurier     boul. de la villette         168.
# 2651121                 serrurier     boul. de la villette         168.
# 2651123                  ébéniste             r. montreuil          50.
# 2651125         fabr. de ressorts             boul. davout  167 et 169.
# 2651126          boucherie hippo.              r. saussure          38.
# 2651131         tailleur p. dames    boul. des batignolles          98.
# 2651132         tailleur p. dames    boul. des batignolles          98.
# 2651133          fleurs et plumes             pass. violet           2.
# 2651134          fleurs et plumes             pass. violet           2.
# 2651135          fleurs et plumes             pass. violet           2.
# 2651137         art. pour fumeurs         boul. de magenta         102.
# 2651138         art. pour fumeurs         boul. de magenta         102.
# 2651139         art. pour fumeurs         boul. de magenta         102.
# 2651140                 ingénieur        boul. malesherbes          91.
# 2651141                 ingénieur        boul. malesherbes          91.
# 2651145          fabr. de peignes            r. des marais          60.
# 2651147                  papetier       r. sambre-et-meuse          32.
# 2651149                serruriers             r. st-victor          14.
# 2651157      polisseur sur métaux       cité des envierges           4.
# 2651160                architecte          boul. garibaldi          33.
# 2651164                mécanicien        boul. de grenelle          56.
# 2651165                mécanicien        boul. de grenelle          56.
# 2651166                mécanicien        boul. de grenelle          56.
# 2651167                mécanicien        boul. de grenelle          56.
# 2651168                mécanicien        boul. de grenelle          56.
# 2651171                ameublem's            r. de flandre          47.
# 2651172                ameublem's            r. de flandre          47.
# 2651176                 ingénieur          boul. haussmann         148.
# 2651179       cuivres artistiques    pass. des patriarches       1 bis.
# 2651180       cuivres artistiques    pass. des patriarches       1 bis.
# 2651185  commiss. en marchandises        pass. de choiseul           4.
# 2651186  commiss. en marchandises        pass. de choiseul           4.
# 2651189      peinture et vitrerie          boul. garibaldi           7.
# 2651194       tailleur pour dames            r. de flandre          68.
# 2651195       tailleur pour dames            r. de flandre          68.
# 2651202           déchets de cuir             r. de buffon          67.
# 7603                     coiffeur  et boulevard montmartre          21.
# 1884443                 joaillier       r. square pétrelle           4.
#
#          annee      N_SQ_VO           L_VOIE             L_COURTMIN  \
# 2651104   1922  750002515.0         voltaire          Cité Voltaire
# 2651105   1922  750003852.0         chapelle     Bd. de la Chapelle
# 2651106   1922  750002391.0         chapelle         Sout. Chapelle
# 2651107   1922  750003853.0         chapelle    Cité de la Chapelle
# 2651108   1922  750006453.0         chapelle    Imp. de la Chapelle
# 2651109   1922  750003854.0         chapelle     Pl. de la Chapelle
# 2651110   1922  750001777.0         chapelle     Av. de la Chapelle
# 2651111   1922  750003855.0         chapelle      R. de la Chapelle
# 2651115   1922  750005764.0         italiens       Bd. des Italiens
# 2651116   1922  750004662.0         italiens        R. des Italiens
# 2651118   1922  750005066.0         villette      R. de la Villette
# 2651119   1922  750005452.0         villette         Sout. Villette
# 2651120   1922  750005065.0         villette     Bd. de la Villette
# 2651121   1922  750005067.0         villette    Gal. de la Villette
# 2651123   1922  750003059.0        montreuil        R. de Montreuil
# 2651125   1922  750003683.0           davout             Bd. Davout
# 2651126   1922  750000812.0         saussure         R. de Saussure
# 2651131   1922  750005051.0      batignolles    Bd. des Batignolles
# 2651132   1922  750001972.0      batignolles     R. des Batignolles
# 2651133   1922  750000613.0           violet              R. Violet
# 2651134   1922  750000612.0           violet             Pl. Violet
# 2651135   1922  750000614.0           violet            Vla. Violet
# 2651137   1922  750004593.0          magenta         Bd. de Magenta
# 2651138   1922  750003115.0          magenta        Cité de Magenta
# 2651139   1922  750006581.0          magenta          R. de Magenta
# 2651140   1922  750004598.0      malesherbes        Bd. Malesherbes
# 2651141   1922  750004599.0      malesherbes       Cité Malesherbes
# 2651145   1922  750003127.0           marais        Pas. des Marais
# 2651147   1922  750006324.0  sambre-et-meuse  R. de Sambre-Et-Meuse
# 2651149   1922  750000680.0           victor             Bd. Victor
# 2651157   1922  750003559.0        envierges       R. des Envierges
# 2651160   1922  750001460.0        garibaldi          Bd. Garibaldi
# 2651164   1922  750001389.0         grenelle       Vla. de Grenelle
# 2651165   1922  750001388.0         grenelle        Qu. de Grenelle
# 2651166   1922  750004696.0         grenelle         R. de Grenelle
# 2651167   1922  750001387.0         grenelle       Port de Grenelle
# 2651168   1922  750001385.0         grenelle        Bd. de Grenelle
# 2651171   1922  750000330.0          flandre         Av. de Flandre
# 2651172   1922  750005282.0          flandre        Pas. de Flandre
# 2651176   1922  750004711.0        haussmann          Bd. Haussmann
# 2651179   1922  750004447.0      patriarches     R. des Patriarches
# 2651180   1922  750004446.0      patriarches   Pas. des Patriarches
# 2651185   1922  750005912.0         choiseul         R. de Choiseul
# 2651186   1922  750005911.0         choiseul          Pas. Choiseul
# 2651189   1922  750001460.0        garibaldi          Bd. Garibaldi
# 2651194   1922  750000330.0          flandre         Av. de Flandre
# 2651195   1922  750005282.0          flandre        Pas. de Flandre
# 2651202   1922  750004943.0           buffon              R. Buffon
# 7603      1855  750005642.0       montmartre         bd. montmartre
# 1884443   1907  750004472.0         petrelle           sq. pétrelle
#
#                          L_LONGMIN  \
# 2651104              Cité Voltaire
# 2651105   Boulevard de la Chapelle
# 2651106        Souterrain Chapelle
# 2651107        Cité de la Chapelle
# 2651108     Impasse de la Chapelle
# 2651109       Place de la Chapelle
# 2651110      Avenue de la Chapelle
# 2651111         Rue de la Chapelle
# 2651115     Boulevard des Italiens
# 2651116           Rue des Italiens
# 2651118         Rue de la Villette
# 2651119        Souterrain Villette
# 2651120   Boulevard de la Villette
# 2651121     Galerie de la Villette
# 2651123           Rue de Montreuil
# 2651125           Boulevard Davout
# 2651126            Rue de Saussure
# 2651131  Boulevard des Batignolles
# 2651132        Rue des Batignolles
# 2651133                 Rue Violet
# 2651134               Place Violet
# 2651135               Villa Violet
# 2651137       Boulevard de Magenta
# 2651138            Cité de Magenta
# 2651139             Rue de Magenta
# 2651140      Boulevard Malesherbes
# 2651141           Cité Malesherbes
# 2651145         Passage des Marais
# 2651147     Rue de Sambre-Et-Meuse
# 2651149           Boulevard Victor
# 2651157          Rue des Envierges
# 2651160        Boulevard Garibaldi
# 2651164          Villa de Grenelle
# 2651165           Quai de Grenelle
# 2651166            Rue de Grenelle
# 2651167           Port de Grenelle
# 2651168      Boulevard de Grenelle
# 2651171          Avenue de Flandre
# 2651172         Passage de Flandre
# 2651176        Boulevard Haussmann
# 2651179        Rue des Patriarches
# 2651180    Passage des Patriarches
# 2651185            Rue de Choiseul
# 2651186           Passage Choiseul
# 2651189        Boulevard Garibaldi
# 2651194          Avenue de Flandre
# 2651195         Passage de Flandre
# 2651202                 Rue Buffon
# 7603          boulevard montmartre
# 1884443            square pétrelle
#
#                                                   Geometry       LENGTH  \
# 2651104  {"coordinates": [[[2.3890787361900028, 48.8524...   276.553915
# 2651105  {"coordinates": [[[2.3512555061916722, 48.8837...  2405.956587
# 2651106  {"coordinates": [[2.3621049852972154, 48.89859...   445.554776
# 2651107  {"coordinates": [[2.3597183866608917, 48.88721...   172.899667
# 2651108  {"coordinates": [[2.359718070687783, 48.892703...    84.194412
# 2651109  {"coordinates": [[2.360791435980116, 48.884530...   253.536635
# 2651110  {"coordinates": [[[2.286812272456765, 48.88084...   133.542170
# 2651111  {"coordinates": [[[2.3598807896913803, 48.8908...  1984.740679
# 2651115  {"coordinates": [[[2.339546440002341, 48.87189...   451.371193
# 2651116  {"coordinates": [[2.335954790381124, 48.871278...   115.898439
# 2651118  {"coordinates": [[2.3874409336821962, 48.87467...   546.824492
# 2651119  {"coordinates": [[2.3925342288068046, 48.89695...  1065.823367
# 2651120  {"coordinates": [[[2.376811238098365, 48.87200...  3241.343520
# 2651121  {"coordinates": [[2.3921161985404487, 48.88880...  1003.781409
# 2651123  {"coordinates": [[2.383951499805109, 48.850467...  1061.144697
# 2651125  {"coordinates": [[[2.4112320184338363, 48.8478...  3249.011720
# 2651126  {"coordinates": [[2.317641377917759, 48.882868...  1295.975825
# 2651131  {"coordinates": [[[2.318828913371657, 48.88163...  1707.345718
# 2651132  {"coordinates": [[2.32409007431169, 48.8829613...   566.128385
# 2651133  {"coordinates": [[2.2950045869361113, 48.84984...   664.348147
# 2651134  {"coordinates": [[2.2902151798923316, 48.84477...    49.069695
# 2651135  {"coordinates": [[2.2911242416806585, 48.84441...    33.179990
# 2651137  {"coordinates": [[[2.3627358056280814, 48.8688...  3886.519367
# 2651138  {"coordinates": [[2.3600406295120693, 48.87184...    93.817437
# 2651139  {"coordinates": [[2.3893445520155416, 48.90111...   110.747063
# 2651140  {"coordinates": [[[2.323459392807408, 48.86974...  2561.516839
# 2651141  {"coordinates": [[2.340210339471365, 48.880790...   163.940956
# 2651145  {"coordinates": [[2.3610187882289493, 48.87115...   146.944356
# 2651147  {"coordinates": [[2.3691681301273544, 48.87531...   392.362556
# 2651149  {"coordinates": [[[2.2874749828400462, 48.8330...  1946.729654
# 2651157  {"coordinates": [[2.3860279246829625, 48.87149...   298.252637
# 2651160  {"coordinates": [[[2.3114822861491673, 48.8452...  1611.205514
# 2651164  {"coordinates": [[2.2942040221331, 48.84892742...    87.182744
# 2651165  {"coordinates": [[[2.281644658671169, 48.84932...  1565.417353
# 2651166  {"coordinates": [[[2.3300292034969887, 48.8522...  2377.334844
# 2651167  {"coordinates": [[2.2884139218889112, 48.85473...   767.318317
# 2651168  {"coordinates": [[[2.2978020858972523, 48.8489...  2600.593041
# 2651171  {"coordinates": [[[2.3688942831857065, 48.8841...  3104.668741
# 2651172  {"coordinates": [[2.3728563032514054, 48.88734...   145.098842
# 2651176  {"coordinates": [[[2.3352351220363263, 48.8726...  2616.079209
# 2651179  {"coordinates": [[2.3508312999752436, 48.84156...   148.819419
# 2651180  {"coordinates": [[2.3507544882697697, 48.84117...    82.808766
# 2651185  {"coordinates": [[2.335939573794966, 48.868878...   266.851978
# 2651186  {"coordinates": [[2.3351089573587145, 48.86717...   199.319113
# 2651189  {"coordinates": [[[2.3114822861491673, 48.8452...  1611.205514
# 2651194  {"coordinates": [[[2.3688942831857065, 48.8841...  3104.668741
# 2651195  {"coordinates": [[2.3728563032514054, 48.88734...   145.098842
# 2651202  {"coordinates": [[2.36426812913778, 48.8432622...   654.354809
# 7603     {"coordinates": [[2.3430689368210826, 48.87148...   228.513283
# 1884443  {"coordinates": [[2.3489980393068475, 48.88056...    53.511103
#
#                                   Geometry X Y aligned_on  \
# 2651104    48.8527066801208,2.3902033886928113     L_VOIE
# 2651105   48.884196292924635,2.357063542137758     L_VOIE
# 2651106   48.898525303304226,2.359068291678964     L_VOIE
# 2651107    48.88730632922413,2.358730766590166     L_VOIE
# 2651108  48.892698728117594,2.3591442172030948     L_VOIE
# 2651109   48.88480648972644,2.3594297765903955     L_VOIE
# 2651110    48.88111616566177,2.286533313908099     L_VOIE
# 2651111   48.894529443910386,2.359500975638578     L_VOIE
# 2651115   48.87151413382537,2.3373363688341864     L_VOIE
# 2651116    48.87178443346516,2.335875254820215     L_VOIE
# 2651118    48.87709708172455,2.387834050991014     L_VOIE
# 2651119     48.8979019193133,2.387984282147387     L_VOIE
# 2651120   48.87853330250509,2.3711868439365635     L_VOIE
# 2651121   48.89250285006341,2.3881374881557353     L_VOIE
# 2651123   48.850595067767614,2.391121464589174     L_VOIE
# 2651125  48.856140497132294,2.4101181118458985     L_VOIE
# 2651126   48.88716129031833,2.3114773965056132     L_VOIE
# 2651131   48.88239098963247,2.3218702809019365     L_VOIE
# 2651132  48.884712631444216,2.3212860808525604     L_VOIE
# 2651133   48.84725653906741,2.2927492145678836     L_VOIE
# 2651134   48.84466286907822,2.2905025954263536     L_VOIE
# 2651135   48.844290580878216,2.291009461869028     L_VOIE
# 2651137    48.87613217190465,2.356188962742278     L_VOIE
# 2651138     48.871645609004766,2.3594847064157     L_VOIE
# 2651139   48.90101479063093,2.3900836977622806     L_VOIE
# 2651140    48.87900110673799,2.314522745876903     L_VOIE
# 2651141   48.88096593731198,2.3392405738043154     L_VOIE
# 2651145   48.871732187744925,2.361487051814981     L_VOIE
# 2651147  48.874840534879745,2.3716897907485377     L_VOIE
# 2651149   48.83484074604318,2.2823058811697963     L_VOIE
# 2651157   48.87222742803884,2.3876492949825576     L_VOIE
# 2651160   48.84648099518195,2.3065524164771256     L_VOIE
# 2651164    48.8491213361704,2.2936877612582816     L_VOIE
# 2651165  48.851254389871386,2.2844540582282904     L_VOIE
# 2651166    48.85666349969438,2.316354231872223     L_VOIE
# 2651167    48.85224632233549,2.284853248580576     L_VOIE
# 2651168    48.85051610643869,2.294709274642154     L_VOIE
# 2651171     48.88956425042015,2.37549380792684     L_VOIE
# 2651172    48.88701149053346,2.373707796786528     L_VOIE
# 2651176   48.87410078464041,2.3220755605562795     L_VOIE
# 2651179  48.840895419728696,2.3506859035967596     L_VOIE
# 2651180    48.84113767019602,2.350193412927933     L_VOIE
# 2651185   48.87007854587347,2.3359547245813297     L_VOIE
# 2651186     48.86802579086045,2.33553829885351     L_VOIE
# 2651189   48.84648099518195,2.3065524164771256     L_VOIE
# 2651194     48.88956425042015,2.37549380792684     L_VOIE
# 2651195    48.88701149053346,2.373707796786528     L_VOIE
# 2651202    48.84224251504861,2.360111387202759     L_VOIE
# 7603       48.8717348555593,2.3415565853614324  L_LONGMIN
# 1884443    48.88079798397406,2.349067020964381  L_LONGMIN
#
#                      no_spaces no_spaces_long no_spaces_court  \
# 2651104           boulvoltaire            NaN             NaN
# 2651105       bouldelachapelle            NaN             NaN
# 2651106       bouldelachapelle            NaN             NaN
# 2651107       bouldelachapelle            NaN             NaN
# 2651108       bouldelachapelle            NaN             NaN
# 2651109       bouldelachapelle            NaN             NaN
# 2651110       bouldelachapelle            NaN             NaN
# 2651111       bouldelachapelle            NaN             NaN
# 2651115        bouldesitaliens            NaN             NaN
# 2651116        bouldesitaliens            NaN             NaN
# 2651118       bouldelavillette            NaN             NaN
# 2651119       bouldelavillette            NaN             NaN
# 2651120       bouldelavillette            NaN             NaN
# 2651121       bouldelavillette            NaN             NaN
# 2651123             rmontreuil            NaN             NaN
# 2651125             bouldavout            NaN             NaN
# 2651126              rsaussure            NaN             NaN
# 2651131     bouldesbatignolles            NaN             NaN
# 2651132     bouldesbatignolles            NaN             NaN
# 2651133             passviolet            NaN             NaN
# 2651134             passviolet            NaN             NaN
# 2651135             passviolet            NaN             NaN
# 2651137          bouldemagenta            NaN             NaN
# 2651138          bouldemagenta            NaN             NaN
# 2651139          bouldemagenta            NaN             NaN
# 2651140        boulmalesherbes            NaN             NaN
# 2651141        boulmalesherbes            NaN             NaN
# 2651145             rdesmarais            NaN             NaN
# 2651147         rsambreetmeuse            NaN             NaN
# 2651149              rstvictor            NaN             NaN
# 2651157       citédesenvierges            NaN             NaN
# 2651160          boulgaribaldi            NaN             NaN
# 2651164         bouldegrenelle            NaN             NaN
# 2651165         bouldegrenelle            NaN             NaN
# 2651166         bouldegrenelle            NaN             NaN
# 2651167         bouldegrenelle            NaN             NaN
# 2651168         bouldegrenelle            NaN             NaN
# 2651171             rdeflandre            NaN             NaN
# 2651172             rdeflandre            NaN             NaN
# 2651176          boulhaussmann            NaN             NaN
# 2651179     passdespatriarches            NaN             NaN
# 2651180     passdespatriarches            NaN             NaN
# 2651185         passdechoiseul            NaN             NaN
# 2651186         passdechoiseul            NaN             NaN
# 2651189          boulgaribaldi            NaN             NaN
# 2651194             rdeflandre            NaN             NaN
# 2651195             rdeflandre            NaN             NaN
# 2651202              rdebuffon            NaN             NaN
# 7603     etboulevardmontmartre            NaN             NaN
# 1884443        rsquarepétrelle            NaN             NaN
#
#                     sans_pref
# 2651104              voltaire
# 2651105              chapelle
# 2651106              chapelle
# 2651107              chapelle
# 2651108              chapelle
# 2651109              chapelle
# 2651110              chapelle
# 2651111              chapelle
# 2651115              italiens
# 2651116              italiens
# 2651118              villette
# 2651119              villette
# 2651120              villette
# 2651121              villette
# 2651123             montreuil
# 2651125                davout
# 2651126              saussure
# 2651131           batignolles
# 2651132           batignolles
# 2651133                violet
# 2651134                violet
# 2651135                violet
# 2651137               magenta
# 2651138               magenta
# 2651139               magenta
# 2651140           malesherbes
# 2651141           malesherbes
# 2651145                marais
# 2651147       sambre-et-meuse
# 2651149                victor
# 2651157             envierges
# 2651160             garibaldi
# 2651164              grenelle
# 2651165              grenelle
# 2651166              grenelle
# 2651167              grenelle
# 2651168              grenelle
# 2651171               flandre
# 2651172               flandre
# 2651176             haussmann
# 2651179           patriarches
# 2651180           patriarches
# 2651185              choiseul
# 2651186              choiseul
# 2651189             garibaldi
# 2651194               flandre
# 2651195               flandre
# 2651202                buffon
# 7603     boulevard montmartre
# 1884443       square pétrelle

# %%
not_aligned.head(50)
# Out:
#        Unnamed: 0  page  row                               Nom  \
# 0   bpt6k6282019m   144    0                             Aaron
# 1   bpt6k6282019m   144    1                      Aaron (Mic.)
# 2   bpt6k6282019m   144    5                            Abadie
# 3   bpt6k6282019m   144    6                            Abanse
# 4   bpt6k6282019m   144   13                 Abault et Coudray
# 5   bpt6k6282019m   144   14                     Abault (Paul)
# 6   bpt6k6282019m   144   15                            Abavid
# 7   bpt6k6282019m   144   16                     Abazaer (Are)
# 8   bpt6k6282019m   144   17         Abbadie (A.) et Montagnan
# 9   bpt6k6282019m   144   20                             Abbal
# 10  bpt6k6282019m   144   25  Abbaye-au-Bois (communauté del')
# 11  bpt6k6282019m   144   26                           Abeille
# 12  bpt6k6282019m   144   27                           Abeille
# 13  bpt6k6282019m   144   28                              Abel
# 14  bpt6k6282019m   144   29                              Abel
# 15  bpt6k6282019m   144   31   Abel de Pujol * (de l'Institut)
# 16  bpt6k6282019m   144   33      Abel-Mouillard et E. Gaspart
# 17  bpt6k6282019m   144   36                             Abert
# 18  bpt6k6282019m   144   38                           Abillot
# 19  bpt6k6282019m   144   39                              Abit
# 20  bpt6k6282019m   144   40                        Abit jeune
# 21  bpt6k6282019m   144   41                             Abler
# 22  bpt6k6282019m   144   42                            Aboire
# 23  bpt6k6282019m   144   43                           Abonnet
# 24  bpt6k6282019m   144   45                      Abraham (E.)
# 25  bpt6k6282019m   144   49          Abraham-Cliver (Edouard)
# 26  bpt6k6282019m   144   52                             Abran
# 27  bpt6k6282019m   144   55                              Abry
# 28  bpt6k6282019m   144   56                         Abry (J.)
# 29  bpt6k6282019m   144   65                              Acar
# 30  bpt6k6282019m   144   73                            Achard
# 31  bpt6k6282019m   144   76                       Achard (A.)
# 32  bpt6k6282019m   144   77                      Achard (Mme)
# 33  bpt6k6282019m   144   79                            Achard
# 34  bpt6k6282019m   144   81                            Achard
# 35  bpt6k6282019m   144   86              Achet de Massy (Mme)
# 36  bpt6k6282019m   144   87                           Achille
# 37  bpt6k6282019m   144   88                           Achille
# 38  bpt6k6282019m   144   90                             Achin
# 39  bpt6k6282019m   144   92                          Achtsnil
# 40  bpt6k6282019m   144   93                             Acker
# 41  bpt6k6282019m   144   94                             Acker
# 42  bpt6k6282019m   144   96                    Ackermann fils
# 43  bpt6k6282019m   144   97                            Acklin
# 44  bpt6k6282019m   144   98                             Aclin
# 45  bpt6k6282019m   144  101       Acloque de St-André (baron)
# 46  bpt6k6282019m   144  102                            Acolas
# 47  bpt6k6282019m   144  103                           A colet
# 48  bpt6k6282019m   144  105                   Acquier-Launois
# 49  bpt6k6282019m   144  109                              Adam
#
#                                        Métier                        Rue  \
# 0                                     bronzes           passage choiseal
# 1                       manuf. de porcelaines                      bondy
# 2                           tabac et estamin.               ménilmontant
# 3                                 instituteur                  sts-pères
# 4                                charpentiers                    corbeau
# 5                                    libraire         quai des angustins
# 6                                        vins       beaujolais-da-temple
# 7                     cristaux et porcelaines                pei.ecuries
# 8                                       draps      neuve-desbons-enfants
# 9                                    coiffeur                 parc-royal
# 10     église succursale de St-Thomas-d'Aquin                     sèvres
# 11                                    médecin                  pépinière
# 12                                  propriét.            faub.-st-honoré
# 13                                  coutelier       paradis-poissonnière
# 14                        coke et escarhilles       austerlitz-st-marcel
# 15                            peintre d'hist.                     albouy
# 16   fab. de châles et confections pour dames             boul. st-denis
# 17                                  boulanger          ecole-de-médecine
# 18                            peintre-vitrier                  pépinière
# 19                                  bonnetier       boul. bonne-nouvelle
# 20                                     propr.         st-maar-popincourt
# 21                      cordonnier pour dames                  st-honoré
# 22                          ligeur de dessins            fontaine-au-roi
# 23                                       vins        st-jean-de-beauvais
# 24                         fabr. de broderies           neuvest-eustache
# 25                       cravates et foulards          neape-st-eustache
# 26                                    bottler         vingt-neuf-juillet
# 27                            ancien libraire           basse-du-rempart
# 28                             fab. de fleurs               ste-apolline
# 29           premier pharmacien de l'Empereur                  st-honoré
# 30                         artiste dramatiqne                     douane
# 31                           homme de lettres                    nayarin
# 32                                      hôtel               saints-pères
# 33                                    meubles         bourbon-villeneuve
# 34                        montures de parapl.                  st-martin
# 35                                 pensionnat             valoisdu-roule
# 36                                   coiffeur           fossés-du-temple
# 37                                   coiffeur                   thévenot
# 38                               bijoutier or  place de l'hôtel-de-ville
# 39                                  lapidaire             enfants-rouges
# 40                             fab. de mottes                   gobeling
# 41                                  papeterie      nve-des-petits-champs
# 42                                    sellier             faub.-st-denis
# 43                                 herboriste          orléans-st-marcel
# 44  appareils en papier pour métiers Jacquard         st-maur-popincourt
# 45                                  propriét.                 penthièyre
# 46                       entrep de charpentes                  lafayette
# 47                                   ciseleur              poitou-marais
# 48                                  fleuriste                   st-denis
# 49           de la maigon Thibert Adam et Cie                    bracque
#
#        Numéro  annee              no_spaces           sans_pref
# 0   72 et 74.   1855        passagechoiseal            choiseal
# 1         30.   1855                  bondy               bondy
# 2        158.   1855           ménilmontant        ménilmontant
# 3         30.   1855               stspères               pères
# 4         23.   1855                corbeau             corbeau
# 5          9.   1855       quaidesangustins           angustins
# 6          7.   1855     beaujolaisdatemple           da-temple
# 7         26.   1855             peiecuries         pei.ecuries
# 8          1.   1855    neuvedesbonsenfants          desenfants
# 9          8.   1855              parcroyal          parc-royal
# 10        16.   1855                 sèvres              sèvres
# 11        39.   1855              pépinière           pépinière
# 12        27.   1855           faubsthonoré              honoré
# 13        59.   1855    paradispoissonnière        poissonnière
# 14        45.   1855     austerlitzstmarcel   austerlitz-marcel
# 15        14.   1855                 albouy              albouy
# 16         9.   1855            boulstdenis               denis
# 17        04.   1855        ecoledemédecine            médecine
# 18        82.   1855              pépinière           pépinière
# 19        11.   1855      boulbonnenouvelle      bonne-nouvelle
# 20       158.   1855       stmaarpopincourt     maar-popincourt
# 21       317.   1855               sthonoré              honoré
# 22         59   1855          fontaineauroi              au-roi
# 23        22.   1855       stjeandebeauvais         de-beauvais
# 24        44.   1855        neuvesteustache       neuveeustache
# 25        36.   1855        neapesteustache      neape-eustache
# 26         5.   1855       vingtneufjuillet  vingt-neuf-juillet
# 27        56.   1855         bassedurempart             rempart
# 28        33.   1855            steapolline            apolline
# 29       313.   1855               sthonoré              honoré
# 30        12.   1855                 douane              douane
# 31        20.   1855                nayarin             nayarin
# 32        55.   1855            saintspères        saints-pères
# 33        57.   1855      bourbonvilleneuve          villeneuve
# 34       293.   1855               stmartin              martin
# 35         4.   1855          valoisduroule      valoisdu-roule
# 36        29.   1855         fossésdutemple           du-temple
# 37        32.   1855               thévenot            thévenot
# 38         7.   1855  placedel'hôteldeville    l'hôtel-de-ville
# 39         1.   1855          enfantsrouges              rouges
# 40         5.   1855               gobeling            gobeling
# 41        29.   1855     nvedespetitschamps          des-champs
# 42       104.   1855            faubstdenis               denis
# 43        44.   1855        orléansstmarcel              marcel
# 44        88.   1855       stmaurpopincourt     maur-popincourt
# 45        34.   1855             penthièyre          penthièyre
# 46        33.   1855              lafayette           lafayette
# 47        22.   1855           poitoumarais       poitou-marais
# 48       309.   1855                stdenis               denis
# 49         2.   1855                bracque             bracque
